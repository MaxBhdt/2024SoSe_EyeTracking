# %%
#Import packages
import numpy as np
import pandas as pd

# Import libraries for plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
sns.set_style("white")

# %%
#import CSV
# loop to define,and append the variables into a list.
df = []
amt = 4 # The amount of properly labeled csv files
for n in range(amt):
    d = pd.read_csv(fr'.\\subject-{n+1}.tsv', sep='\t')
    #F-strings ('f' before the opening quotation mark) provide a way to embed variables and expressions directly within strings.  
    df.append(d)
    #If you want to call subject3 (df3), you can call df[3], if you want df5, call df[5], etc.
    # Test whether data is a Pandas DataFrame
    assert isinstance(df[n], pd.DataFrame) == True

# %%
# Sample subject to visualize (you can change this)
subject_index = 0  # For example 2, to visualize subject 3

# Select the relevant DataFrame
data = df[subject_index]

# %%
#display 5 rows of 1st participant
data.head(5)
# Out:
#       CNT        TIME    TIME_TICK    FPOGX    FPOGY       FPOGS    FPOGD  \
# 0  366720  2469.64282  25055996241  0.41575  0.44991  2468.91260  0.71704
# 1  366721  2469.64917  25056060241  0.41576  0.45110  2468.91260  0.71704
# 2  366722  2469.65601  25056128267  0.41577  0.45170  2469.63623  0.01978
# 3  366723  2469.66260  25056194034  0.41456  0.45278  2469.63623  0.02637
# 4  366724  2469.66943  25056261799  0.41366  0.45458  2469.63623  0.03320
#
#    FPOGID  FPOGV    LPOGX  ...  LPUPILV    REYEX    REYEY    REYEZ  RPUPILD  \
# 0    5930      0  0.42794  ...        1  0.05366  0.01797  0.63225  0.00455
# 1    5930      0  0.42649  ...        1  0.05366  0.01797  0.63225  0.00454
# 2    5931      1  0.42649  ...        1  0.05437  0.01816  0.64062  0.00457
# 3    5931      1  0.41969  ...        1  0.05437  0.01816  0.64062  0.00455
# 4    5931      1  0.41723  ...        1  0.05437  0.01816  0.64062  0.00455
#
#    RPUPILV       CX       CY  CS         USER
# 0        1  0.26667  0.35556   0            0
# 1        1  0.26667  0.35556   0  START_TRIAL
# 2        1  0.26667  0.35556   0          NaN
# 3        1  0.26667  0.35556   0          NaN
# 4        1  0.26667  0.35556   0          NaN
#
# [5 rows x 42 columns]

# %%
#test the dataset with a displot
#Use FPOGID instead of count to get Valid Counts (One fixation gets many counts)
sns.displot(df[0], x='FPOGX')

# %%
#test the dataset with a displot
sns.displot(df[0], x='FPOGD')

# %%
# **Time vs. X Plot**
sns.lineplot(data=data, x="TIME", y="FPOGX")
sns.lineplot(data=data, x="TIME", y="BPOGX")
plt.title(f"Subject {subject_index + 1} - X Position over Time")
plt.xlabel("Time")
plt.ylabel("X Position")
plt.show()

# %%
# **Time vs. X Plot**
sns.lineplot(data=data, x="TIME", y="FPOGX")
#sns.lineplot(data=data, x="TIME", y="BPOGX")
# Zoom in on the x-axis between 0.6 and 0.7
plt.xlim(2505, 2530)
plt.title(f"Subject {subject_index + 1} - X Position over Time")
plt.xlabel("Time")
plt.ylabel("X Position")
plt.show()

# %%
# **Time vs. Y Plot**
sns.lineplot(data=data, x="TIME", y="FPOGY")
plt.title(f"Subject {subject_index + 1} - Y Position over Time")
plt.xlabel("Time")
plt.ylabel("Y Position")
plt.show()

# %%
# **Time vs. Y Plot**
sns.lineplot(data=data, x="TIME", y="FPOGY")
# Zoom in on the x-axis between 0.6 and 0.7
plt.xlim(2505, 2530)
plt.title(f"Subject {subject_index + 1} - Y Position over Time")
plt.xlabel("Time")
plt.ylabel("Y Position")
plt.show()

# %%
# **X vs. Y Plot (Gaze Path)**
#sns.scatterplot(data=data, x="FPOGX", y="FPOGY", s=40, hue='FPOGID')  # Use scatterplot for gaze path
sns.lineplot(data=data, x="FPOGX", y="FPOGY", marker='o', sort =False)  # Use scatterplot for gaze path
# Zoom in on the x-axis between 0.6 and 0.7

plt.title(f"Subject {subject_index + 1} - Gaze Path")
plt.xlabel("X Position")
plt.ylabel("Y Position")
plt.show()

# %%
# **X vs. Y Plot (Gaze Path)**
#sns.scatterplot(data=data, x="FPOGX", y="FPOGY", s=40, hue='FPOGID')  # Use scatterplot for gaze path
sns.lineplot(data=data, x="FPOGX", y="FPOGY", marker='o', sort =False)  # Use scatterplot for gaze path
# Zoom in on the x-axis between 0.6 and 0.7
plt.xlim(0.45, 0.55)
plt.ylim(0.45, 0.55)
plt.title(f"Subject {subject_index + 1} - Gaze Path")
plt.xlabel("X Position")
plt.ylabel("Y Position")
plt.show()
